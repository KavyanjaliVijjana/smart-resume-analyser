# %% [markdown]
# # Day 3 - Resume Scoring
#
# ## Objective
#
# The objective of this notebook is to compare extracted resume skills with required job skills and generate a resume matching score using keyword-based analysis.
