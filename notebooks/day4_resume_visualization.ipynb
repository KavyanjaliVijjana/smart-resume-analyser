# %% [markdown]
# # Day 4 - Resume Analytics Visualization
#
# ## Objective
#
# The objective of this notebook is to visualize resume analytics such as extracted skills, ATS score, and missing skills using Matplotlib.

# %% [markdown]
# # Final Insights
#
# 1. Python and SQL appeared as the most frequent extracted skills.
#
# 2. ATS score visualization helped evaluate candidate-job alignment.
#
# 3. Missing skills analysis identified areas requiring improvement.
#
# 4. Visualization made resume analytics easier to understand and interpret.

# %% [markdown]
# # Business Recommendations
#
# 1. Recommend personalized learning paths for missing skills.
#
# 2. Improve candidate-job matching using better skill extraction.
#
# 3. Use analytics dashboards to simplify recruiter screening workflows.
#
# 4. Expand ATS logic to include projects, certifications, and experience.
