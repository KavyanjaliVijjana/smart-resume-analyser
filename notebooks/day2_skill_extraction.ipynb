# %% [markdown]
# # Day 2 - Skill Extraction
#
# ## Objective
#
# The objective of this notebook is to extract technical skills from resumes using keyword matching and basic NLP preprocessing techniques.
